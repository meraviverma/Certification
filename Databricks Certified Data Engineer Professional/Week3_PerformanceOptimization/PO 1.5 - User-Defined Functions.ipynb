# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img
#     src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png"
#     alt="Databricks Learning"
#   >
# </div>

# %% [markdown]
# # User-Defined Functions
#
# Databricks recommends using native functions whenever possible. While UDFs are a great way to extend the functionality of Spark SQL, their use requires transferring data between Python and Spark, which in turn requires serialization. This drastically slows down queries.
#
# But sometimes UDFs are necessary. They can be an especially powerful tool for ML or NLP use cases, which may not have a native Spark equivalent.
#
# Run the next cell to set up the lesson.

# %% [markdown]
# ## REQUIRED - SELECT A CLASSIC COMPUTE ENVIRONMENT
#
# <div style="
#   border-left: 4px solid #f44336;
#   background: #ffebee;
#   padding: 14px 18px;
#   border-radius: 4px;
#   margin: 16px 0;
# ">
#   <strong style="display:block; color:#c62828; margin-bottom:6px; font-size: 1.1em;">Select Classic Compute</strong>
#   <div style="color:#333;">
#
# Before executing cells in this notebook, please select your classic compute cluster in the lab. Be aware that **Serverless** is enabled by default. If you use Serverless, errors will be returned when setting compute runtime properties. Select the required compute environment listed below.
#
# - **Classic Compute (version = 15.4 LTS)**
# </br>
#
# <img src="./Includes/images/common/select-classic-compute.png" alt="Compute Select" width="400"/>
# <br></br>
#
# **NOTE:** If your cluster has terminated, you might need to restart it in order to select it. To do this:
#
# 1. Right-click on **Compute** in the left navigation pane and select *Open in new tab*.
#
# 1. Find the triangle icon to the right of your compute cluster name and click it.
#
# 1. Wait a few minutes for the cluster to start.
#
# 1. Once the cluster is running, complete the steps above to select your cluster.
#   </div>
# </div>

# %% [markdown]
# ## A. Classroom Setup
#
# Run the following cell to configure your working environment for this course. It will also set your perf_opt catalog to your unique **labuser** catalog, and the default schema to **perf_opt**. All tables will be read from and written to this location.
# <br></br>

# %%
# %run ./Includes/Classroom-Setup-5
# Out:
# ✅ Vocareum workspace detected.
# ✅ Using existing Vocareum catalog: 'labuser12306723_1783168710'.
# Set the spark.sql.autoBroadcastJoinThreshold and spark.databricks.adaptive.autoBroadcastJoinThreshold configs to the defaults.
# Creating schema labuser12306723_1783168710.perf_opt...
# DataFrame[]
# <table style="width:100%">
#         <tr>
#             <td style="white-space:nowrap; width:1em">Course Catalog:</td>
#             <td><input type="text" value="labuser12306723_1783168710" style="width: 100%"></td></tr>
#         <tr>
#             <td style="white-space:nowrap; width:1em">Your Schema:</td>
#             <td><input type="text" value="perf_opt" style="width: 100%"></td></tr></table>
# ------------------------------------------------------------------------------
# ✅ SETUP COMPLETE!
# ------------------------------------------------------------------------------

# %% [markdown]
# Let's Check the Current Catalog and Schema

# %%
# %sql
SELECT current_catalog(), current_schema()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_catalog()</th><th>current_schema()</th></tr></thead><tbody><tr><td>labuser12306723_1783168710</td><td>perf_opt</td></tr></tbody></table></div>

# %% [markdown]
# ## B. Disable Caching
#
# Run the following cell to set a Spark configuration variable that disables disk caching.
#
# Turning disk caching off prevents Databricks from storing cloud storage files after the first query. This makes the effect of the optimizations more apparent by ensuring that files are always pulled from cloud storage for each query.
#
# For more information, see Optimize performance with caching on Databricks:
# [AWS](https://docs.databricks.com/aws/en/optimizations/disk-cache) |
# [Azure](https://learn.microsoft.com/en-us/azure/databricks/optimizations/disk-cache) |
# [GCP](https://docs.databricks.com/gcp/en/optimizations/disk-cache).
#
# **NOTE:** This will not work in Serverless. Please use classic compute to turn off caching. If you're using Serverless, an error will be returned.

# %%
spark.conf.set('spark.databricks.io.cache.enabled', False)

# %% [markdown]
# ## C. Generate Data
#
# Let's generate the data we will use in this demo. For this, we'll synthesize telemetry data representing temperature readings. This time, however, we're only going to generate 60 readings and create a table named **device_data**.

# %%
from pyspark.sql.functions import *

## Drop the table if it exists
spark.sql('DROP TABLE IF EXISTS device_data')


## Create the table
spark.sql('DROP TABLE IF EXISTS device_data')

df = (spark
      .range(0, 60, 1, 1)
      .select(
          'id',
          (col('id') % 1000).alias('device_id'),
          (rand() * 100).alias('temperature_F')
      )
      .write
      .saveAsTable('device_data')
)

## Display the table
display(spark.sql('SELECT * FROM device_data'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>device_id</th><th>temperature_F</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>73.95970394984599</td></tr><tr><td>1</td><td>1</td><td>77.29669067892745</td></tr><tr><td>2</td><td>2</td><td>20.002884813963064</td></tr><tr><td>3</td><td>3</td><td>85.13851337616615</td></tr><tr><td>4</td><td>4</td><td>7.4305255736941795</td></tr><tr><td>5</td><td>5</td><td>16.835798946589065</td></tr><tr><td>6</td><td>6</td><td>81.07167843740885</td></tr><tr><td>7</td><td>7</td><td>70.27155795451255</td></tr><tr><td>8</td><td>8</td><td>74.33303628111975</td></tr><tr><td>9</td><td>9</td><td>57.916447347407676</td></tr><tr><td>10</td><td>10</td><td>52.191425168669326</td></tr><tr><td>11</td><td>11</td><td>62.82776714223511</td></tr><tr><td>12</td><td>12</td><td>0.21660156270489894</td></tr><tr><td>13</td><td>13</td><td>54.858066842805286</td></tr><tr><td>14</td><td>14</td><td>56.793180456444105</td></tr><tr><td>15</td><td>15</td><td>66.3328730765091</td></tr><tr><td>16</td><td>16</td><td>98.6568910781119</td></tr><tr><td>17</td><td>17</td><td>42.71702096505666</td></tr><tr><td>18</td><td>18</td><td>38.273165529333454</td></tr><tr><td>19</td><td>19</td><td>45.614506194218585</td></tr><tr><td>20</td><td>20</td><td>5.273961987782039</td></tr><tr><td>21</td><td>21</td><td>96.02606602982362</td></tr><tr><td>22</td><td>22</td><td>34.74530386512622</td></tr><tr><td>23</td><td>23</td><td>60.91527073136193</td></tr><tr><td>24</td><td>24</td><td>65.3800541084543</td></tr><tr><td>25</td><td>25</td><td>27.6025892684966</td></tr><tr><td>26</td><td>26</td><td>80.54718707939645</td></tr><tr><td>27</td><td>27</td><td>78.4314592623827</td></tr><tr><td>28</td><td>28</td><td>88.78106507111022</td></tr><tr><td>29</td><td>29</td><td>44.286402494922136</td></tr><tr><td>30</td><td>30</td><td>96.72593897222865</td></tr><tr><td>31</td><td>31</td><td>51.644388820351224</td></tr><tr><td>32</td><td>32</td><td>14.72305701836546</td></tr><tr><td>33</td><td>33</td><td>30.29426867668419</td></tr><tr><td>34</td><td>34</td><td>69.61026284854171</td></tr><tr><td>35</td><td>35</td><td>80.87205473681139</td></tr><tr><td>36</td><td>36</td><td>95.6194761916519</td></tr><tr><td>37</td><td>37</td><td>90.60611939387235</td></tr><tr><td>38</td><td>38</td><td>58.03172078507374</td></tr><tr><td>39</td><td>39</td><td>57.636539233157094</td></tr><tr><td>40</td><td>40</td><td>79.0813866180772</td></tr><tr><td>41</td><td>41</td><td>13.646853512110512</td></tr><tr><td>42</td><td>42</td><td>60.38486318660416</td></tr><tr><td>43</td><td>43</td><td>33.85282770568372</td></tr><tr><td>44</td><td>44</td><td>38.684004695259446</td></tr><tr><td>45</td><td>45</td><td>44.46003015855583</td></tr><tr><td>46</td><td>46</td><td>41.816662599847454</td></tr><tr><td>47</td><td>47</td><td>63.57422891597777</td></tr><tr><td>48</td><td>48</td><td>12.156625025964985</td></tr><tr><td>49</td><td>49</td><td>47.80138947921889</td></tr><tr><td>50</td><td>50</td><td>10.023808307472859</td></tr><tr><td>51</td><td>51</td><td>2.4611026270461744</td></tr><tr><td>52</td><td>52</td><td>35.10893450930968</td></tr><tr><td>53</td><td>53</td><td>77.43028305295093</td></tr><tr><td>54</td><td>54</td><td>59.899005739439794</td></tr><tr><td>55</td><td>55</td><td>49.88828428068764</td></tr><tr><td>56</td><td>56</td><td>55.66972731101409</td></tr><tr><td>57</td><td>57</td><td>10.77267213311387</td></tr><tr><td>58</td><td>58</td><td>73.49843899924234</td></tr><tr><td>59</td><td>59</td><td>52.63293912526912</td></tr></tbody></table></div>

# %% [markdown]
# ## D. Python UDF
# Create and use a Python UDF in two ways.
# - Computationally Expensive Python UDF
# - Parallelizing a Python UDF through Repartitioning

# %% [markdown]
# ### D1. Computationally Expensive Python UDF
#
# For the sake of experimentation, let's implement a function that converts Fahrenheit to Celsius. Notice that we're inserting a one-second sleep to simulate a computationally expensive operation within our UDF. Let's try it.

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *
import time

## Create the Python UDF
@udf("double")
def F_to_Celsius(f):
    # Let's pretend some fancy math takes one second per row
    time.sleep(1)
    return (f - 32) * (5/9)

spark.sql('DROP TABLE IF EXISTS celsius')

## Prep the data
celsius_df = (spark
              .table('device_data')
              .withColumn("celsius", F_to_Celsius(col('temperature_F')))
            )

## Create the table
(celsius_df
 .write
 .mode('overwrite')
 .saveAsTable('celsius')
)

# %% [markdown]
# Run the code to view how many partitions were used for the query. Notice that only **1 partition** was used because the UDF does not utilize the parallel processing capabilities of Spark, which slows down the query.

# %%
print(f'Total number of cores across all executors in the cluster: {spark.sparkContext.defaultParallelism}')
print(f'The number of partitions in the underlying RDD of a dataframe: {celsius_df.rdd.getNumPartitions()}')
# Out:
# Total number of cores across all executors in the cluster: 4
# The number of partitions in the underlying RDD of a dataframe: 1

# %% [markdown]
# Explain the Spark execution plan. Notice that the **BatchEvalPython** stage indicates that a Python UDF is being used.

# %%
celsius_df.explain()
# Out:
# == Physical Plan ==
# *(2) Project [id#4571L, device_id#4572L, temperature_F#4573, pythonUDF0#5075 AS celsius#4578]
# +- BatchEvalPython [F_to_Celsius(temperature_F#4573)#4577], [pythonUDF0#5075]
#    +- *(1) ColumnarToRow
#       +- PhotonResultStage
#          +- PhotonScan parquet labuser12306723_1783168710.perf_opt.device_data[id#4571L,device_id#4572L,temperature_F#4573] DataFilters: [], DictionaryFilters: [], Format: parquet, Location: PreparedDeltaFileIndex(1 paths)[s3://unity-catalogs-us-west-2/metastore/4635643-root/423834ea-ade..., OptionalDataFilters: [], PartitionFilters: [], ReadSchema: struct<id:bigint,device_id:bigint,temperature_F:double>, RequiredDataFilters: []
#
#
# == Photon Explanation ==
# Photon does not fully support the query because:
# 		Unsupported node: BatchEvalPython [F_to_Celsius(temperature_F#4573)#4577], [pythonUDF0#5075].
#
# Reference node:
# 	BatchEvalPython [F_to_Celsius(temperature_F#4573)#4577], [pythonUDF0#5075]

# %% [markdown]
# #### Summary
# That took approximately one minute, which is kind of surprising since we have about 60 seconds worth of computation, spread across multiple cores. Shouldn't it take significantly less time?
#
# The answer to this question is yes, it should take less time. The problem here is that Spark doesn't know that the computations are expensive, so it hasn't divided the work up into tasks that can be done in parallel. We can see that by watching the one task chug away as the cell is running, and by visiting the Spark UI.

# %% [markdown]
# ### D2. Parallelizing a Python UDF through Repartitioning
#
# Repartitioning is the answer in this case. *We* know that this computation is expensive and should span across all 4 cores, so we can explicitly repartition the DataFrame:

# %%
# Repartition across the number of cores in your cluster
num_cores = 4

@udf("double")
def F_to_Celsius(f):
    # Let's pretend some fancy math takes one second per row
    time.sleep(1)
    return (f - 32) * (5/9)

spark.sql('DROP TABLE IF EXISTS celsius')

celsius_df_cores = (spark.table('device_data')
                    .repartition(num_cores) # <-- HERE
                    .withColumn("celsius", F_to_Celsius(col('temperature_F')))
             )

(celsius_df_cores
 .write
 .mode('overwrite')
 .saveAsTable('celsius')
)

# %% [markdown]
# Run the code to view how many partitions are being used for the query. Notice that 4 partitions (tasks) are being used to execute the code in parallel.

# %%
print(f'Total number of cores across all executors in the cluster: {spark.sparkContext.defaultParallelism}')
print(f'The number of partitions in the underlying RDD of a dataframe: {celsius_df_cores.rdd.getNumPartitions()}')
# Out:
# Total number of cores across all executors in the cluster: 4
# The number of partitions in the underlying RDD of a dataframe: 4

# %% [markdown]
# #### Summary
# The repartition command is a recommended best practice to ensure your UDF runs in a parallel, distributed manner.

# %% [markdown]
# ##E. SQL UDFs
#
# The ability to create user-defined functions in Python and Scala is convenient since it allows you to extend functionality in the language of your choice. As far as optimization is concerned, however, it's important to know that SQL is generally the best choice, for a couple of reasons:
# - SQL UDFs require less data serialization
# - Catalyst optimizer can operate within SQL UDFs
#
# Let's see this in action now by comparing the performance of a SQL UDF to its Python counterpart.
#
# First let's redefine the Python UDF from before, this time without the delay, so we can compare raw performance.

# %% [markdown]
# Now let's perform the equivalent operation through a SQL UDF.

# %%
# %sql

-- Create the same function
DROP FUNCTION IF EXISTS farh_to_cels;

CREATE FUNCTION farh_to_cels (farh DOUBLE)
  RETURNS DOUBLE RETURN ((farh - 32) * 5/9);


-- Use the function to create the table
DROP TABLE IF EXISTS celsius_sql;

CREATE OR REPLACE TABLE celsius_sql AS
SELECT farh_to_cels(temperature_F) as Farh_to_cels_convert 
FROM device_data;


-- View the data
SELECT * 
FROM celsius_sql;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Farh_to_cels_convert</th></tr></thead><tbody><tr><td>23.310946638803326</td></tr><tr><td>25.164828154959693</td></tr><tr><td>-6.665063992242742</td></tr><tr><td>29.521396320092304</td></tr><tr><td>-13.649708014614344</td></tr><tr><td>-8.424556140783853</td></tr><tr><td>27.26204357633825</td></tr><tr><td>21.26197664139586</td></tr><tr><td>23.51835348951097</td></tr><tr><td>14.398026304115376</td></tr><tr><td>11.217458427038515</td></tr><tr><td>17.126537301241726</td></tr><tr><td>-17.657443576275057</td></tr><tr><td>12.698926023780714</td></tr><tr><td>13.773989142468947</td></tr><tr><td>19.07381837583839</td></tr><tr><td>37.03160615450661</td></tr><tr><td>5.95390053614259</td></tr><tr><td>3.485091960740808</td></tr><tr><td>7.563614552343659</td></tr><tr><td>-14.847798895676647</td></tr><tr><td>35.570036683235344</td></tr><tr><td>1.5251688139590098</td></tr><tr><td>16.064039295201074</td></tr><tr><td>18.544474504696836</td></tr><tr><td>-2.4430059619463327</td></tr><tr><td>26.970659488553583</td></tr><tr><td>25.795255145768166</td></tr><tr><td>31.545036150616788</td></tr><tr><td>6.825779163845631</td></tr><tr><td>35.95885498457147</td></tr><tr><td>10.91354934463957</td></tr><tr><td>-9.598301656463633</td></tr><tr><td>-0.9476285129532277</td></tr><tr><td>20.89459047141206</td></tr><tr><td>27.15114152045077</td></tr><tr><td>35.344153439806604</td></tr><tr><td>32.55895521881797</td></tr><tr><td>14.462067102818743</td></tr><tr><td>14.242521796198385</td></tr><tr><td>26.15632589893178</td></tr><tr><td>-10.196192493271939</td></tr><tr><td>15.769368437002308</td></tr><tr><td>1.029348725379846</td></tr><tr><td>3.7133359418108034</td></tr><tr><td>6.9222389769754615</td></tr><tr><td>5.453701444359697</td></tr><tr><td>17.541238286654316</td></tr><tr><td>-11.024097207797231</td></tr><tr><td>8.778549710677161</td></tr><tr><td>-12.2089953847373</td></tr><tr><td>-16.410498540529904</td></tr><tr><td>1.727185838505376</td></tr><tr><td>25.23904614052829</td></tr><tr><td>15.499447633022108</td></tr><tr><td>9.937935711493134</td></tr><tr><td>13.149848506118941</td></tr><tr><td>-11.79295992604785</td></tr><tr><td>23.054688332912413</td></tr><tr><td>11.462743958482843</td></tr></tbody></table></div>

# %% [markdown]
# Explain the query plan with the SQL UDF. Notice that the SQL UDF is fully supported by Photon and is more performant.

# %%
# %sql
EXPLAIN 
SELECT farh_to_cels(temperature_F) as Farh_to_cels_convert 
FROM device_data
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>plan</th></tr></thead><tbody><tr><td>== Physical Plan ==
# *(1) ColumnarToRow
# +- PhotonResultStage
#    +- PhotonProject [(((temperature_F#6188 - 32.0) * 5.0) / 9.0) AS Farh_to_cels_convert#6167]
#       +- PhotonScan parquet labuser12306723_1783168710.perf_opt.device_data[temperature_F#6188] DataFilters: [], DictionaryFilters: [], Format: parquet, Location: PreparedDeltaFileIndex(1 paths)[s3://unity-catalogs-us-west-2/metastore/4635643-root/423834ea-ade..., OptionalDataFilters: [], PartitionFilters: [], ReadSchema: struct<temperature_F:double>, RequiredDataFilters: []
#
#
# == Photon Explanation ==
# The query is fully supported by Photon.</td></tr></tbody></table></div>

# %% [markdown]
# ## Summary
#
# Actual times depend on a number of factors, however, on average, the SQL UDF will perform better than its Python equivalent — often, significantly better. The reason for this is that SQL UDFs use Spark's built-in APIs and functions, rather than relying on external dependencies or Python UDFs.
#
# If you are using a UDF in your Spark job, refactoring your code to use native Spark APIs or functions whenever possible will lead to the best performance and efficiency gains.
#
# If you must use UDFs due to strong dependencies on external libraries, you should parallelize your code and repartition your DataFrame to match the number of CPU cores in your cluster to achieve the best level of parallelization.
#
# When using Python UDFs, consider using **Apache Arrow**-optimized Python UDFs instead, as they improve the efficiency of data exchange between the Spark runtime and the UDF process. [Learn more about Arrow-optimized Python UDFs](https://www.databricks.com/blog/arrow-optimized-python-udfs-apache-sparktm-35).

# %% [markdown]
# &copy; 2026 Databricks, Inc. All rights reserved. Apache, Apache Spark, Spark, the Spark Logo, Apache Iceberg, Iceberg, and the Apache Iceberg logo are trademarks of the <a href="https://www.apache.org/" target="_blank">Apache Software Foundation</a>.<br/><br/><a href="https://databricks.com/privacy-policy" target="_blank">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use" target="_blank">Terms of Use</a> | <a href="https://help.databricks.com/" target="_blank">Support</a>
